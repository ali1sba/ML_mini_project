# %%
import pandas as pd

# %%
 urltrain = ("/Users/mac/Desktop/MesCours/datamining/dataset/train.csv")
urltest = ("/Users/mac/Desktop/MesCours/datamining/dataset/test.csv")
urlstay = ("/Users/mac/Desktop/MesCours/datamining/dataset/sample_submission.csv")

# %%
HealthTrain = pd.read_csv( urltrain)
HealthTest = pd.read_csv( urltest)
HealthStay = pd.read_csv( urlstay)

# %%
HealthTrain.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                                  3  radiotherapy
# 1                    Z                                  2  radiotherapy
# 2                    X                                  2    anesthesia
# 3                    Y                                  2  radiotherapy
# 4                    Y                                  2  radiotherapy
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         R                  F        2.0      31397                7.0
# 1         S                  F        2.0      31397                7.0
# 2         S                  E        2.0      31397                7.0
# 3         R                  D        2.0      31397                7.0
# 4         S                  D        2.0      31397                7.0
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency             Extreme                      2  51-60
# 1            Trauma             Extreme                      2  51-60
# 2            Trauma             Extreme                      2  51-60
# 3            Trauma             Extreme                      2  51-60
# 4            Trauma             Extreme                      2  51-60
#
#    Admission_Deposit   Stay
# 0             4911.0   0-10
# 1             5954.0  41-50
# 2             4745.0  31-40
# 3             7272.0  41-50
# 4             5558.0  41-50

# %%
HealthTrain = HealthTrain.drop("Stay", axis=1)

# %%
HealthTrain.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                                  3  radiotherapy
# 1                    Z                                  2  radiotherapy
# 2                    X                                  2    anesthesia
# 3                    Y                                  2  radiotherapy
# 4                    Y                                  2  radiotherapy
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         R                  F        2.0      31397                7.0
# 1         S                  F        2.0      31397                7.0
# 2         S                  E        2.0      31397                7.0
# 3         R                  D        2.0      31397                7.0
# 4         S                  D        2.0      31397                7.0
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency             Extreme                      2  51-60
# 1            Trauma             Extreme                      2  51-60
# 2            Trauma             Extreme                      2  51-60
# 3            Trauma             Extreme                      2  51-60
# 4            Trauma             Extreme                      2  51-60
#
#    Admission_Deposit
# 0             4911.0
# 1             5954.0
# 2             4745.0
# 3             7272.0
# 4             5558.0

# %%
HealthTest.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0   318439             21                  c                   3
# 1   318440             29                  a                   4
# 2   318441             26                  b                   2
# 3   318442              6                  a                   6
# 4   318443             28                  b                  11
#
#   Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                    Z                                  3  gynecology
# 1                    X                                  2  gynecology
# 2                    Y                                  3  gynecology
# 3                    X                                  3  gynecology
# 4                    X                                  2  gynecology
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         S                  A        2.0      17006                2.0
# 1         S                  F        2.0      17006                2.0
# 2         Q                  D        4.0      17006                2.0
# 3         Q                  F        2.0      17006                2.0
# 4         R                  F        2.0      17006                2.0
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency            Moderate                      2  71-80
# 1            Trauma            Moderate                      4  71-80
# 2         Emergency            Moderate                      3  71-80
# 3            Trauma            Moderate                      3  71-80
# 4            Trauma            Moderate                      4  71-80
#
#    Admission_Deposit
# 0             3095.0
# 1             4018.0
# 2             4492.0
# 3             4173.0
# 4             4161.0

# %%
HealthStay.head()
# Out:
#    case_id  Stay
# 0   318439  0-10
# 1   318440  0-10
# 2   318441  0-10
# 3   318442  0-10
# 4   318443  0-10

# %%
import matplotlib.pyplot as plt

# %%
HealthTrain["Age"].hist(bins=5)
# Out:
# <AxesSubplot:>

# %%
plt.show()

# %%
import numpy as np

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc = MinMaxScaler()

# %%
HealthTrain["Bed Grade"] = sc.fit_transform(HealthTrain[["Bed Grade"]])
HealthTest["Bed Grade"] = sc.fit_transform(HealthTest[["Bed Grade"]])

# %%
HealthTrain["Available Extra Rooms in Hospital"] = sc.fit_transform(HealthTrain[["Available Extra Rooms in Hospital"]])
HealthTest["Available Extra Rooms in Hospital"] = sc.fit_transform(HealthTest[["Available Extra Rooms in Hospital"]])

# %%
HealthTrain["Visitors with Patient"] = sc.fit_transform(HealthTrain[["Visitors with Patient"]])
HealthTest["Visitors with Patient"] = sc.fit_transform(HealthTest[["Visitors with Patient"]])

# %%
HealthTrain.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                           0.125000  radiotherapy
# 1                    Z                           0.083333  radiotherapy
# 2                    X                           0.083333    anesthesia
# 3                    Y                           0.083333  radiotherapy
# 4                    Y                           0.083333  radiotherapy
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         R                  F   0.333333      31397                7.0
# 1         S                  F   0.333333      31397                7.0
# 2         S                  E   0.333333      31397                7.0
# 3         R                  D   0.333333      31397                7.0
# 4         S                  D   0.333333      31397                7.0
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency             Extreme                 0.0625  51-60
# 1            Trauma             Extreme                 0.0625  51-60
# 2            Trauma             Extreme                 0.0625  51-60
# 3            Trauma             Extreme                 0.0625  51-60
# 4            Trauma             Extreme                 0.0625  51-60
#
#    Admission_Deposit
# 0             4911.0
# 1             5954.0
# 2             4745.0
# 3             7272.0
# 4             5558.0

# %%
HealthTest.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0   318439             21                  c                   3
# 1   318440             29                  a                   4
# 2   318441             26                  b                   2
# 3   318442              6                  a                   6
# 4   318443             28                  b                  11
#
#   Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                    Z                           0.142857  gynecology
# 1                    X                           0.095238  gynecology
# 2                    Y                           0.142857  gynecology
# 3                    X                           0.142857  gynecology
# 4                    X                           0.095238  gynecology
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         S                  A   0.333333      17006                2.0
# 1         S                  F   0.333333      17006                2.0
# 2         Q                  D   1.000000      17006                2.0
# 3         Q                  F   0.333333      17006                2.0
# 4         R                  F   0.333333      17006                2.0
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency            Moderate                0.06250  71-80
# 1            Trauma            Moderate                0.12500  71-80
# 2         Emergency            Moderate                0.09375  71-80
# 3            Trauma            Moderate                0.09375  71-80
# 4            Trauma            Moderate                0.12500  71-80
#
#    Admission_Deposit
# 0             3095.0
# 1             4018.0
# 2             4492.0
# 3             4173.0
# 4             4161.0

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
classifier = KNeighborsClassifier(n_neighbors = 3, metric = 'minkowski', p = 2)

# %%
HealthStay = HealthTrain.drop("case_id", axis=1)
